# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler



df = pd.read_csv(
    "https://raw.githubusercontent.com/vignesh-creator/machine-learning-/refs/heads/main/student_performance_updated_1000%20(3).csv"
)

print("Dataset Information:")
print(df.info())

print("\nDataset Shape:")
print(df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nFirst 5 Rows:")
print(df.head())

print("\nStatistical Summary:")
print(df.describe())

print("\nMissing Values Before Handling:")
print(df.isnull().sum())




df.fillna(df.mean(numeric_only=True), inplace=True)


for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].fillna(df[col].mode()[0])

print("\nMissing Values After Handling:")
print(df.isnull().sum())



print("\nNumber of Duplicate Rows:")
print(df.duplicated().sum())



df.drop_duplicates(inplace=True)

print("\nDataset Shape After Removing Duplicates:")
print(df.shape)



le = LabelEncoder()

for col in df.select_dtypes(include="object").columns:
    df[col] = le.fit_transform(df[col])

print("\nEncoded Dataset:")
print(df.head())



scaler = StandardScaler()

num_cols = df.select_dtypes(include=["int64", "float64"]).columns

df[num_cols] = scaler.fit_transform(df[num_cols])

print("\nScaled Dataset:")
print(df.head())



print("\nFinal Dataset Information:")
print(df.info())

print("\nFinal Statistical Summary:")
print(df.describe())

print("\nFinal Dataset Shape:")
print(df.shape)

print("\nFinal Missing Values:")
print(df.isnull().sum())

# 11. Display Final Preprocessed Dataset

print("\nFinal Preprocessed Dataset:")
print(df.head())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  960 non-null    float64
#  1   Name                       966 non-null    object
#  2   Gender                     952 non-null    object
#  3   AttendanceRate             960 non-null    float64
#  4   StudyHoursPerWeek          950 non-null    float64
#  5   PreviousGrade              967 non-null    float64
#  6   ExtracurricularActivities  957 non-null    float64
#  7   ParentalSupport            978 non-null    object
#  8   FinalGrade                 960 non-null    float64
#  9   Study Hours                976 non-null    float64
#  10  Attendance (%)             959 non-null    float64
#  11  Online Classes Taken       975 non-null    object
# dtypes: float64(8), object(4)
# memory usage: 93.9+ KB
# None
#
# Dataset Shape:
# (1000, 12)
#
# Column Names:
# Index(['StudentID', 'Name', 'Gender', 'AttendanceRate', 'StudyHoursPerWeek',
#        'PreviousGrade', 'ExtracurricularActivities', 'ParentalSupport',
#        'FinalGrade', 'Study Hours', 'Attendance (%)', 'Online Classes Taken'],
#       dtype='object')
#
# First 5 Rows:
#    StudentID     Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0        1.0     John    Male            85.0               15.0
# 1        2.0    Sarah  Female            90.0               20.0
# 2        3.0     Alex    Male            78.0               10.0
# 3        4.0  Michael    Male            92.0               25.0
# 4        5.0     Emma  Female             NaN               18.0
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# 0           78.0                        1.0            High        80.0
# 1           85.0                        2.0          Medium        87.0
# 2           65.0                        0.0             Low        68.0
# 3           90.0                        3.0            High        92.0
# 4           82.0                        2.0          Medium        85.0
#
#    Study Hours  Attendance (%) Online Classes Taken
# 0          4.8            59.0                False
# 1          2.2            70.0                 True
# 2          4.6            92.0                False
# 3          2.9            96.0                False
# 4          4.1            97.0                 True
#
# Statistical Summary:
#          StudentID  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# count   960.000000      960.000000         950.000000     967.000000
# mean   5416.019792       85.510417          17.630526      77.598759
# std    2653.748319        7.332125           6.272132      10.006640
# min       1.000000       70.000000           8.000000      60.000000
# 25%    3113.500000       82.000000          12.000000      70.000000
# 50%    5396.500000       88.000000          18.000000      78.000000
# 75%    7754.750000       91.000000          22.000000      86.000000
# max    9998.000000       95.000000          30.000000      90.000000
#
#        ExtracurricularActivities  FinalGrade  Study Hours  Attendance (%)
# count                 957.000000  960.000000   976.000000      959.000000
# mean                    1.520376   80.030208     2.406967       77.248175
# std                     1.046439    9.493652     1.620267       19.298148
# min                     0.000000   62.000000    -5.000000       50.000000
# 25%                     1.000000   72.000000     1.200000       63.000000
# 50%                     1.000000   80.000000     2.500000       76.000000
# 75%                     2.000000   88.000000     3.700000       89.000000
# max                     3.000000   92.000000     5.000000      200.000000
#
# Missing Values Before Handling:
# StudentID                    40
# Name                         34
# Gender                       48
# AttendanceRate               40
# StudyHoursPerWeek            50
# PreviousGrade                33
# ExtracurricularActivities    43
# ParentalSupport              22
# FinalGrade                   40
# Study Hours                  24
# Attendance (%)               41
# Online Classes Taken         25
# dtype: int64
#
# Missing Values After Handling:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# Study Hours                  0
# Attendance (%)               0
# Online Classes Taken         0
# dtype: int64
#
# Number of Duplicate Rows:
# 0
#
# Dataset Shape After Removing Duplicates:
# (1000, 12)
#
# Encoded Dataset:
#    StudentID  Name  Gender  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# 0        1.0   427       1       85.000000               15.0           78.0
# 1        2.0   826       0       90.000000               20.0           85.0
# 2        3.0    12       1       78.000000               10.0           65.0
# 3        4.0   646       1       92.000000               25.0           90.0
# 4        5.0   299       0       85.510417               18.0           82.0
#
#    ExtracurricularActivities  ParentalSupport  FinalGrade  Study Hours  \
# 0                        1.0                0        80.0          4.8
# 1                        2.0                2        87.0          2.2
# 2                        0.0                1        68.0          4.6
# 3                        3.0                0        92.0          2.9
# 4                        2.0                2        85.0          4.1
#
#    Attendance (%)  Online Classes Taken
# 0            59.0                 False
# 1            70.0                  True
# 2            92.0                 False
# 3            96.0                 False
# 4            97.0                  True
#
# Scaled Dataset:
#    StudentID      Name    Gender  AttendanceRate  StudyHoursPerWeek  \
# 0  -2.083680 -0.132554  0.906363   -7.108626e-02          -0.430521
# 1  -2.083295  1.271050 -1.103311    6.252690e-01           0.387796
# 2  -2.082910 -1.592443  0.906363   -1.045984e+00          -1.248838
# 3  -2.082526  0.637845  0.906363    9.038110e-01           1.206114
# 4  -2.082141 -0.582833 -1.103311    1.979161e-15           0.060469
#
#    PreviousGrade  ExtracurricularActivities  ParentalSupport  FinalGrade  \
# 0       0.040797                  -0.508598        -1.154002   -0.003249
# 1       0.752537                   0.468768         1.247668    0.749682
# 2      -1.281005                  -1.485964         0.046833   -1.293989
# 3       1.260922                   1.446134        -1.154002    1.287490
# 4       0.447505                   0.468768         1.247668    0.534559
#
#    Study Hours  Attendance (%)  Online Classes Taken
# 0     1.495753       -0.966098                 False
# 1    -0.129364       -0.383734                  True
# 2     1.370744        0.780993                 False
# 3     0.308168        0.992762                 False
# 4     1.058221        1.045704                  True
#
# Final Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  1000 non-null   float64
#  1   Name                       1000 non-null   float64
#  2   Gender                     1000 non-null   float64
#  3   AttendanceRate             1000 non-null   float64
#  4   StudyHoursPerWeek          1000 non-null   float64
#  5   PreviousGrade              1000 non-null   float64
#  6   ExtracurricularActivities  1000 non-null   float64
#  7   ParentalSupport            1000 non-null   float64
#  8   FinalGrade                 1000 non-null   float64
#  9   Study Hours                1000 non-null   float64
#  10  Attendance (%)             1000 non-null   float64
#  11  Online Classes Taken       1000 non-null   bool
# dtypes: bool(1), float64(11)
# memory usage: 87.0 KB
# None
#
# Final Statistical Summary:
#           StudentID          Name        Gender  AttendanceRate  \
# count  1.000000e+03  1.000000e+03  1.000000e+03    1.000000e+03
# mean   3.712586e-16  4.973799e-17 -1.154632e-16    1.360689e-15
# std    1.000500e+00  1.000500e+00  1.000500e+00    1.000500e+00
# min   -2.083680e+00 -1.634657e+00 -1.103311e+00   -2.160152e+00
# 25%   -8.347271e-01 -8.827261e-01 -1.103311e+00   -4.888994e-01
# 50%    3.499703e-16 -7.672331e-03  9.063629e-01    1.979161e-15
# 75%    8.663614e-01  8.673815e-01  9.063629e-01    7.645400e-01
# max    1.763129e+00  1.745953e+00  9.063629e-01    1.321624e+00
#
#        StudyHoursPerWeek  PreviousGrade  ExtracurricularActivities  \
# count       1.000000e+03   1.000000e+03               1.000000e+03
# mean       -8.082424e-17   5.755396e-16              -9.059420e-17
# std         1.000500e+00   1.000500e+00               1.000500e+00
# min        -1.576165e+00  -1.789391e+00              -1.485964e+00
# 25%        -9.215114e-01  -7.726198e-01              -5.085980e-01
# 50%         0.000000e+00   4.079702e-02               0.000000e+00
# 75%         7.151232e-01   8.542139e-01               4.687680e-01
# max         2.024431e+00   1.260922e+00               1.446134e+00
#
#        ParentalSupport    FinalGrade   Study Hours  Attendance (%)
# count     1.000000e+03  1.000000e+03  1.000000e+03    1.000000e+03
# mean      7.993606e-18 -1.622702e-15 -3.268497e-16    3.410605e-16
# std       1.000500e+00  1.000500e+00  1.000500e+00    1.000500e+00
# min      -1.154002e+00 -1.939359e+00 -4.629687e+00   -1.442577e+00
# 25%      -1.154002e+00 -8.637423e-01 -7.544086e-01   -7.013869e-01
# 50%       4.683257e-02 -1.528543e-15  2.907483e-02   -1.313893e-02
# 75%       1.247668e+00  8.572438e-01  8.082035e-01    6.221669e-01
# max       1.247668e+00  1.287490e+00  1.620762e+00    6.498746e+00
#
# Final Dataset Shape:
# (1000, 12)
#
# Final Missing Values:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# Study Hours                  0
# Attendance (%)               0
# Online Classes Taken         0
# dtype: int64
#
# Final Preprocessed Dataset:
#    StudentID      Name    Gender  AttendanceRate  StudyHoursPerWeek  \
# 0  -2.083680 -0.132554  0.906363   -7.108626e-02          -0.430521
# 1  -2.083295  1.271050 -1.103311    6.252690e-01           0.387796
# 2  -2.082910 -1.592443  0.906363   -1.045984e+00          -1.248838
# 3  -2.082526  0.637845  0.906363    9.038110e-01           1.206114
# 4  -2.082141 -0.582833 -1.103311    1.979161e-15           0.060469
#
#    PreviousGrade  ExtracurricularActivities  ParentalSupport  FinalGrade  \
# 0       0.040797                  -0.508598        -1.154002   -0.003249
# 1       0.752537                   0.468768         1.247668    0.749682
# 2      -1.281005                  -1.485964         0.046833   -1.293989
# 3       1.260922                   1.446134        -1.154002    1.287490
# 4       0.447505                   0.468768         1.247668    0.534559
#
#    Study Hours  Attendance (%)  Online Classes Taken
# 0     1.495753       -0.966098                 False
# 1    -0.129364       -0.383734                  True
# 2     1.370744        0.780993                 False
# 3     0.308168        0.992762                 False
# 4     1.058221        1.045704                  True
# C:\Users\Vignesh\AppData\Local\Temp\ipykernel_27644\3101651013.py:38: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(df[col].mode()[0])
